# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
x = np.arange(0,10,0.01)
y = np.sin(x)
plt.plot(x,y)
plt.title('arbitrary graph')

# %%
x = np.arange(0,10,0.01)
y = np.cos(x)
plt.plot(x,y)
plt.title('some other arbitrary graph')
